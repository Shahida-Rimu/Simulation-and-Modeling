# %%
import numpy as np
from sympy import Matrix
import matplotlib.pyplot as plt
import seaborn as sns
# Sample scalar and array inputs
scalar = 3.7
arr = np.array([12, 22, 13, 4, 25, 33])

# Trigonometric functions
sin_values = np.sin(arr)
cos_values = np.cos(arr)
tan_values = np.tan(arr)
asin_values = np.arcsin(np.clip(arr / np.max(arr), -1, 1))  # Normalized and Clipping for valid range [-1, 1]
acos_values = np.arccos(np.clip(arr / np.max(arr), -1, 1))
atan_values = np.arctan(arr)

# Exponential and logarithm
exp_values = np.exp(arr)
log_values = np.log(arr)  # Natural logarithm

# Absolute value and square root
abs_values = np.abs(arr)
sqrt_values = np.sqrt(arr)

# Remainder when divided by a scalar (e.g., 2)
rem_values = np.remainder(arr, 2)

# Rounding functions
round_values = np.round(arr)
floor_values = np.floor(arr)
ceil_values = np.ceil(arr)

# Display results
print("sin:", sin_values)
print("cos:", cos_values)
print("tan:", tan_values)
print("asin:", asin_values)
print("acos:", acos_values)
print("atan:", atan_values)
print("exp:", exp_values)
print("log:", log_values)
print("abs:", abs_values)
print("sqrt:", sqrt_values)
print("rem:", rem_values)
print("round:", round_values)
print("floor:", floor_values)
print("ceil:", ceil_values)
# Out:
# sin: [-0.53657292 -0.00885131  0.42016704 -0.7568025  -0.13235175  0.99991186]
# cos: [ 0.84385396 -0.99996083  0.90744678 -0.65364362  0.99120281 -0.01327675]
# tan: [-6.35859929e-01  8.85165604e-03  4.63021133e-01  1.15782128e+00
#  -1.33526407e-01 -7.53130148e+01]
# asin: [0.37216853 0.72972766 0.40491365 0.12151092 0.85959116 1.57079633]
# acos: [1.19862779 0.84106867 1.16588268 1.44928541 0.71120517 0.        ]
# atan: [1.48765509 1.52537305 1.49402444 1.32581766 1.53081764 1.54050257]
# exp: [1.62754791e+05 3.58491285e+09 4.42413392e+05 5.45981500e+01
#  7.20048993e+10 2.14643580e+14]
# log: [2.48490665 3.09104245 2.56494936 1.38629436 3.21887582 3.49650756]
# abs: [12 22 13  4 25 33]
# sqrt: [3.46410162 4.69041576 3.60555128 2.         5.         5.74456265]
# rem: [0 0 1 0 1 1]
# round: [12 22 13  4 25 33]
# floor: [12. 22. 13.  4. 25. 33.]
# ceil: [12. 22. 13.  4. 25. 33.]

# %%
import numpy as np
from sympy import Matrix
import matplotlib.pyplot as plt
import seaborn as sns
# Creating a 3x2 matrix
matrix = np.array([[1, 2, ], [3, 4], [5, 8]])

# Trigonometric functions
sin_values = np.sin(matrix)
cos_values = np.cos(matrix)
tan_values = np.tan(matrix)
asin_values = np.arcsin(np.clip(matrix / np.max(matrix), -1, 1))  # Clipping for valid range [-1, 1]
acos_values = np.arccos(np.clip(matrix / np.max(matrix), -1, 1))
atan_values = np.arctan(matrix)

# Exponential and logarithm
exp_values = np.exp(matrix)
log_values = np.log(matrix)  # Natural logarithm (log base e)

# Absolute value and square root
abs_values = np.abs(matrix)
sqrt_values = np.sqrt(matrix)

# Remainder when divided by a scalar (e.g., 2)
rem_values = np.remainder(matrix, 2)

# Rounding functions
round_values = np.round(matrix)
floor_values = np.floor(matrix)
ceil_values = np.ceil(matrix)

# Display results
print("Matrix:\n", matrix)
print("\nsin:\n", sin_values)
print("\ncos:\n", cos_values)
print("\ntan:\n", tan_values)
print("\nasine:\n", asin_values)
print("\nacosine:\n", acos_values)
print("\natangent:\n", atan_values)
print("\nexp:\n", exp_values)
print("\nlog (natural):\n", log_values)
print("\nabs:\n", abs_values)
print("\nsqrt:\n", sqrt_values)
print("\nrem (remainder when divided by 2):\n", rem_values)
print("\nround:\n", round_values)
print("\nfloor:\n", floor_values)
print("\nceil:\n", ceil_values)
# Out:
# Matrix:
#  [[1 2]
#  [3 4]
#  [5 8]]
#
# sin:
#  [[ 0.84147098  0.90929743]
#  [ 0.14112001 -0.7568025 ]
#  [-0.95892427  0.98935825]]
#
# cos:
#  [[ 0.54030231 -0.41614684]
#  [-0.9899925  -0.65364362]
#  [ 0.28366219 -0.14550003]]
#
# tan:
#  [[ 1.55740772 -2.18503986]
#  [-0.14254654  1.15782128]
#  [-3.38051501 -6.79971146]]
#
# asine:
#  [[0.12532783 0.25268026]
#  [0.38439677 0.52359878]
#  [0.67513153 1.57079633]]
#
# acosine:
#  [[1.4454685  1.31811607]
#  [1.18639955 1.04719755]
#  [0.89566479 0.        ]]
#
# atangent:
#  [[0.78539816 1.10714872]
#  [1.24904577 1.32581766]
#  [1.37340077 1.44644133]]
#
# exp:
#  [[2.71828183e+00 7.38905610e+00]
#  [2.00855369e+01 5.45981500e+01]
#  [1.48413159e+02 2.98095799e+03]]
#
# log (natural):
#  [[0.         0.69314718]
#  [1.09861229 1.38629436]
#  [1.60943791 2.07944154]]
#
# abs:
#  [[1 2]
#  [3 4]
#  [5 8]]
#
# sqrt:
#  [[1.         1.41421356]
#  [1.73205081 2.        ]
#  [2.23606798 2.82842712]]
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Define a 2×3 matrix with float values
mat = np.array([[2.1, 4.7, 1.5],
                [3.3, 0.9, 5.8]])

# Flattened version for operations like max, min, etc.
flat_mat = mat.flatten()

# 1. Max & Min values with indices
max_value = np.max(flat_mat)
max_index = np.argmax(flat_mat)
min_value = np.min(flat_mat)
min_index = np.argmin(flat_mat)

# Convert flat index to 2D index
max_index_2d = np.unravel_index(max_index, mat.shape)
min_index_2d = np.unravel_index(min_index, mat.shape)

# 2. Length of the "vectorized" matrix (total elements)
vec_length = flat_mat.size

# 3. Sorted version
sorted_entire_desc = np.sort(flat_mat)[::-1]  # Entire matrix sorted in descending order
sorted_rowwise_desc = -np.sort(-mat, axis=1)  # Row-wise descending sort

# 4. Sum & Product
sum_values = np.sum(flat_mat)
prod_values = np.prod(flat_mat)

# 5. Median, Mean, Standard Deviation
median_value = np.median(flat_mat)
mean_value = np.mean(flat_mat)
std_dev = np.std(flat_mat)

# Display Results
print("Original Matrix:\n", mat)
print("Max value:", max_value, "at index", max_index_2d)
print("Min value:", min_value, "at index", min_index_2d)
print("Length of matrix (flattened):", vec_length)
print("Sorted (entire matrix, descending):", sorted_entire_desc)
print("Sorted (row-wise, descending):\n", sorted_rowwise_desc)
print("Sum of elements:", sum_values)
print("Product of elements:", prod_values)
print("Median value:", median_value)
print("Mean value:", mean_value)
print("Standard deviation:", std_dev)
# Out:
# Original Matrix:
#  [[2.1 4.7 1.5]
#  [3.3 0.9 5.8]]
# Max value: 5.8 at index (np.int64(1), np.int64(2))
# Min value: 0.9 at index (np.int64(1), np.int64(1))
# Length of matrix (flattened): 6
# Sorted (entire matrix, descending): [5.8 4.7 3.3 2.1 1.5 0.9]
# Sorted (row-wise, descending):
#  [[4.7 2.1 1.5]
#  [5.8 3.3 0.9]]
# Sum of elements: 18.3
# Product of elements: 255.03093
# Median value: 2.7
# Mean value: 3.0500000000000003
# Standard deviation: 1.7452315987665743

# %%
# Replace static matrix with random numbers
random_matrix = np.random.uniform(0, 10, size=(3, 2)) # Generate a 3x2 matrix with random floats between 0 and 10

# Perform operations on the random matrix
sin_values_rand = np.sin(random_matrix)
cos_values_rand = np.cos(random_matrix)
tan_values_rand = np.tan(random_matrix)
asin_values_rand = np.arcsin(np.clip(random_matrix / np.max(random_matrix), -1, 1))
acos_values_rand = np.arccos(np.clip(random_matrix / np.max(random_matrix), -1, 1))
atan_values_rand = np.arctan(random_matrix)
exp_values_rand = np.exp(random_matrix)
log_values_rand = np.log(random_matrix)
abs_values_rand = np.abs(random_matrix)
sqrt_values_rand = np.sqrt(random_matrix)
rem_values_rand = np.remainder(random_matrix, 2)
round_values_rand = np.round(random_matrix)
floor_values_rand = np.floor(random_matrix)
ceil_values_rand = np.ceil(random_matrix)

# Display results for the random matrix
print("\nRandom Matrix:\n", random_matrix)
print("\nsin (random):\n", sin_values_rand)
print("\ncos (random):\n", cos_values_rand)
print("\ntan (random):\n", tan_values_rand)
print("\nasine (random):\n", asin_values_rand)
print("\nacosine (random):\n", acos_values_rand)
print("\natangent (random):\n", atan_values_rand)
print("\nexp (random):\n", exp_values_rand)
print("\nlog (natural, random):\n", log_values_rand)
print("\nabs (random):\n", abs_values_rand)
print("\nsqrt (random):\n", sqrt_values_rand)
print("\nrem (remainder when divided by 2, random):\n", rem_values_rand)
print("\nround (random):\n", round_values_rand)
print("\nfloor (random):\n", floor_values_rand)
print("\nceil (random):\n", ceil_values_rand)


# Visualize the random matrix using a heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(random_matrix, annot=True, cmap="viridis", fmt=".2f", linewidths=.5)
plt.title("Heatmap of Random Matrix Values")
plt.xlabel("Column Index")
plt.ylabel("Row Index")
plt.show()
# Out:
# Random Matrix:
#  [[9.2970583  5.08770975]
#  [5.76743772 7.01117199]
#  [9.13834416 8.78757354]]
#
# sin (random):
#  [[ 0.12737271 -0.93039009]
#  [-0.49318533  0.66536801]
#  [ 0.28253312  0.59495079]]
#
# cos (random):
#  [[-0.99185492  0.36657099]
#  [ 0.86992427  0.74651551]
#  [-0.95925754 -0.80376213]]
#
# tan (random):
#  [[-0.12841869 -2.53808979]
#  [-0.56692904  0.8912983 ]
#  [-0.29453312 -0.74020755]]
#
# asine (random):
#  [[1.57079633 0.57906148]
#  [0.66918991 0.85432531]
#  [1.38575455 1.23820467]]
#
# acosine (random):
#  [[0.         0.99173484]
#  [0.90160642 0.71647102]
#  [0.18504178 0.33259166]]
#
# atangent (random):
#  [[1.46364737 1.37671825]
#  [1.39911594 1.42912236]
#  [1.46180099 1.4574867 ]]
#
# exp (random):
#  [[10905.89009394   162.01837421]
#  [  319.71747701  1108.95342236]
#  [ 9305.34424681  6552.31391332]]
#
# log (natural, random):
#  [[2.22969804 1.62682778]
#  [1.75222791 1.94750487]
#  [2.21247921 2.17333863]]
#
# abs (random):
# ...
